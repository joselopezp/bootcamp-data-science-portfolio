# %% [markdown]
# # Phase 3: Data Preparation
#
# **Project**: [Project Name]
# **Author**: Jose Marcel Lopez Pino
# **Date**: [YYYY-MM-DD]
# **Framework**: CRISP-DM + Lean
#
# ---
#
# ## Objective
#
# Clean and transform data for analysis. Apply only transformations
# that serve the business question.
#
# **Lean Filter**: Minimum viable transformations.

# %%
import numpy as np
import pandas as pd

import sys
sys.path.append('..')
from config.config import DATA_RAW, DATA_PROCESSED, DATA_FINAL
from src.data_processing import clean_data, validate_data

# %% [markdown]
# ## 3.1 Load Data from Phase 2

# %%
# df = pd.read_csv(DATA_RAW / 'filename.csv')

# %% [markdown]
# ## 3.2 Cleaning Steps
#
# Each transformation documented with rationale.

# %%
# Step 1: [Description]
# Rationale: [Why this transformation adds value]

# %% [markdown]
# ## 3.3 Validation

# %%
# validation = validate_data(df_clean)
# print(validation)

# %% [markdown]
# ## 3.4 Save Processed Data

# %%
# df_clean.to_csv(DATA_PROCESSED / 'dataset_clean.csv', index=False)
# print(f'Saved: {len(df_clean)} rows, {len(df_clean.columns)} columns')

# %% [markdown]
# ---
#
# **Previous**: [02_data_understanding.ipynb](./02_data_understanding.ipynb)
# **Next**: [04_modeling.ipynb](./04_modeling.ipynb)
