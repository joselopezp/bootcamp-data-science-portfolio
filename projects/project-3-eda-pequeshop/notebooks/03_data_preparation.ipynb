# %% [markdown]
# # Phase 3: Data Preparation
#
# > **Note:** This phase was completed in **Project 2 (Module 3 — Data Preparation)**.
# > See: [Module_3_Data_Preparation](https://github.com/joselopezp/bootcamp-data-science-portfolio/blob/main/projects/project-2-pequeshop-analytics/notebooks/data_preparation.ipynb) — Lessons 4-6
# >
# > **Summary:** Full ETL pipeline with schema harmonization, date standardization,
# > categorical encoding, missing value imputation, outlier detection (IQR + Z-score hybrid),
# > feature engineering (15+ new columns), NPS classification, and retargeting segmentation.
# >
# > **Lean Principle:** Zero re-work. Project 3 loads the clean datasets directly.
# > No additional preparation needed — straight to EDA (notebook 04).

# %% [markdown]
# ---
#
# **Previous**: [02_data_understanding.ipynb](./02_data_understanding.ipynb)
# **Next**: [04_modeling.ipynb](./04_modeling.ipynb)
