# %% [markdown]
# # Phase 2: Data Understanding
#
# **Project**: [Project Name]
# **Author**: Jose Marcel Lopez Pino
# **Date**: [YYYY-MM-DD]
# **Framework**: CRISP-DM + Lean
#
# ---
#
# ## Objective
#
# Explore and understand the data. Focus on variables relevant
# to the business questions defined in Phase 1.
#
# **Lean Filter**: Only explore what informs the decision.

# %%
# Standard imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Project imports
import sys
sys.path.append('..')
from config.config import DATA_RAW

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
# %matplotlib inline

# %% [markdown]
# ## 2.1 Data Collection

# %%
# Load raw data
# df = pd.read_csv(DATA_RAW / 'filename.csv')
# df.head()

# %% [markdown]
# ## 2.2 Initial Exploration

# %%
# Shape, dtypes, basic info
# print(f'Shape: {df.shape}')
# print(f'\nData types:\n{df.dtypes}')
# print(f'\nMissing values:\n{df.isnull().sum()}')

# %% [markdown]
# ## 2.3 Data Quality Assessment
#
# | Issue | Variable(s) | Severity | Action Needed |
# |-------|-------------|----------|---------------|
# | [e.g., Missing values] | [column] | [High/Med/Low] | [Plan] |

# %% [markdown]
# ## 2.4 Key Observations
#
# - [Observation relevant to business question]
# - [Data limitation to consider]

# %% [markdown]
# ---
#
# **Previous**: [01_business_understanding.ipynb](./01_business_understanding.ipynb)
# **Next**: [03_data_preparation.ipynb](./03_data_preparation.ipynb)
