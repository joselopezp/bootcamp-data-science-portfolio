# %% [markdown]
# # Phase 2: Data Understanding
#
# > **Note:** This phase was completed in **Project 2 (Module 3 — Data Preparation)**.
# > See: [Module_3_Data_Preparation](https://github.com/joselopezp/bootcamp-data-science-portfolio/blob/main/projects/project-2-pequeshop-analytics/notebooks/data_preparation.ipynb) — Lessons 2-3
# >
# > **Summary:** Data extracted from 3 sources (CSV, Excel, HTML), 500 customers registered,
# > 392 with transactions (108 never purchased). 1,192 clean transactions after ETL pipeline.
# >
# > **Key findings from IDA:** Missing values imputed (median/mode), outliers capped at P99,
# > schema harmonization across platforms, NPS surveys integrated.
# >
# > Processed datasets used as input for this project:
# > - `data/processed/transactions_final.csv` (1,192 rows × 15 columns)
# > - `data/processed/customers_final.csv` (392 rows × 12 columns)

# %% [markdown]
# ---
#
# **Previous**: [01_business_understanding.ipynb](./01_business_understanding.ipynb)
# **Next**: [03_data_preparation.ipynb](./03_data_preparation.ipynb)
