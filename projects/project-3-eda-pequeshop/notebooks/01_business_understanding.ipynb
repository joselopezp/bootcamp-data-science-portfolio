# %% [markdown]
# # Phase 1: Business Understanding
#
# **Project**: [Project Name]
# **Author**: Jose Marcel Lopez Pino
# **Date**: [YYYY-MM-DD]
# **Framework**: CRISP-DM + Lean
#
# ---
#
# ## Objective
#
# Define the business problem, success criteria, and project scope.
#
# **Lean Filter**: What specific decision will this analysis enable?

# %% [markdown]
# ## 1.1 Business Problem Statement
#
# | Attribute | Description |
# |-----------|-------------|
# | **Problem** | [What is the business problem?] |
# | **Stakeholder** | [Who needs this analysis?] |
# | **Current Situation** | [What is happening now?] |
# | **Desired Outcome** | [What should change?] |
# | **Cost of Inaction** | [What happens if we do nothing?] |

# %% [markdown]
# ## 1.2 Business Questions
#
# 1. [Primary question — the one that drives the decision]
# 2. [Secondary question]
# 3. [Secondary question]

# %% [markdown]
# ## 1.3 Success Criteria
#
# | Criterion | Metric | Target |
# |-----------|--------|--------|
# | [Business criterion] | [How to measure] | [What counts as success] |

# %% [markdown]
# ## 1.4 Project Scope (Lean: Eliminate Waste)
#
# **In Scope**:
# - [Analysis that directly answers the business questions]
#
# **Out of Scope** (consciously excluded):
# - [Analysis that does NOT contribute to the decision — documented waste]

# %% [markdown]
# ## 1.5 Data Requirements
#
# | Data Needed | Source | Availability | Priority |
# |-------------|--------|-------------|----------|
# | [Variable/dataset] | [Where to get it] | [Available/Pending] | [High/Medium/Low] |

# %% [markdown]
# ## 1.6 Minimum Viable Analysis (MVA)
#
# **What is the simplest analysis that provides value?**
#
# [Describe the MVA — the first deliverable that answers the question,
# even if partially. This guides Phase 2-4 priorities.]

# %% [markdown]
# ---
#
# **Next Phase**: [02_data_understanding.ipynb](./02_data_understanding.ipynb)
