# %% [markdown]
# # Phase 1: Business Understanding
#
# > **Note:** This phase was completed in **Project 2 (Module 3 — Data Preparation)**.
# > See: [Module_3_Data_Preparation](https://github.com/joselopezp/bootcamp-data-science-portfolio/blob/main/projects/project-2-pequeshop-analytics/notebooks/data_preparation.ipynb) — Lessons 1-2
# >
# > **Summary:** PequeShop is a Chilean e-commerce (children's clothing, ages 4-10)
# > operating on MercadoLibre + Shopify. The business problem is understanding
# > customer behavior to improve retention, pricing, and channel optimization.
# >
# > **KPIs defined:** NPS Score, Churn Rate, Revenue, Avg Ticket, CAC, Retargeting Segments.
# >
# > This project (Project 3, Module 4) continues as **CRISP-DM Cycle 2: Diagnostic Analytics**.

# %% [markdown]
# ---
#
# **Next Phase**: [02_data_understanding.ipynb](./02_data_understanding.ipynb)
